# %%
def add(a,b):
    return a + b

print(add(1,2))
print(add(4,5))
print(add(6,7))

# %%
def sum_list(values):
    if len(values) == 0:
        return 0
    else:
        return add(values[0], sum_list(values[1:]))

a = [1,2,3,4,5]
print(sum_list(a))
