# %%
def subtract(a, b):
    return a -b 
print(subtract(8,5))
# Out:
# 3

# %%
def distance_from_zero(x):
    if x<0:
        return subtract(0,x)
    else:
        return subtract(x,0)
print(distance_from_zero(-5))
